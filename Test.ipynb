# %%
print("Hello World")
# Out:
# Hello World

# %%
print("First commit")
# Out:
# First commit

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\vinay\Downloads\Invistico_Airline.csv")
data.shape
# Out:
# (129880, 22)

# %%
data.head()
# Out:
#   satisfaction   Customer Type  Age   Type of Travel     Class  \
# 0    satisfied  Loyal Customer   65  Personal Travel       Eco
# 1    satisfied  Loyal Customer   47  Personal Travel  Business
# 2    satisfied  Loyal Customer   15  Personal Travel       Eco
# 3    satisfied  Loyal Customer   60  Personal Travel       Eco
# 4    satisfied  Loyal Customer   70  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0              265             0                                  0
# 1             2464             0                                  0
# 2             2138             0                                  0
# 3              623             0                                  0
# 4              354             0                                  0
#
#    Food and drink  Gate location  ...  Online support  Ease of Online booking  \
# 0               0              2  ...               2                       3
# ...

# %%
from sklearn.model_selection import train_test_split as tts

# %%
label=data['satisfaction']

# %%
label.tail()
# Out:
# 129875   NaN
# 129876   NaN
# 129877   NaN
# 129878   NaN
# 129879   NaN
# Name: satisfaction, dtype: float64

# %%
data['satisfaction']=data['satisfaction'].map({'satisfied':1, 'dissatisfied':0})
data.head()
# Out:
#    satisfaction  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0           NaN            NaN   65             NaN    NaN              265
# 1           NaN            NaN   47             NaN    NaN             2464
# 2           NaN            NaN   15             NaN    NaN             2138
# 3           NaN            NaN   60             NaN    NaN              623
# 4           NaN            NaN   70             NaN    NaN              354
#
#    Seat comfort  Departure/Arrival time convenient  Food and drink  \
# 0             0                                  0               0
# 1             0                                  0               0
# 2             0                                  0               0
# 3             0                                  0               0
# 4             0                                  0               0
#
#    Gate location  ...  Online support  Ease of Online booking  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   satisfaction                       0 non-null       float64
#  1   Customer Type                      129880 non-null  object
#  2   Age                                129880 non-null  int64
#  3   Type of Travel                     129880 non-null  object
#  4   Class                              129880 non-null  object
#  5   Flight Distance                    129880 non-null  int64
#  6   Seat comfort                       129880 non-null  int64
#  7   Departure/Arrival time convenient  129880 non-null  int64
#  8   Food and drink                     129880 non-null  int64
#  9   Gate location                      129880 non-null  int64
#  10  Inflight wifi service              129880 non-null  int64
# ...

# %%
s1=set()
for i in data1['Customer Type']:
    s1.add(i)
s1
# Out:
# {'Loyal Customer', 'disloyal Customer'}

# %%
data['Customer Type']=data['Customer Type'].map({'Loyal Customer':1, 'disloyal Customer':0})

# %%
def numeric(x):
    s=set()
    for i in data1[x]:
        s.add(i)
    return s

# %%
numeric('Class')
# Out:
# {'Business', 'Eco', 'Eco Plus'}

# %%
data['Class']=data['Class'].map({'Business':1, 'Eco':2, 'Eco Plus':3})

# %%
numeric('Type of Travel')
# Out:
# {'Business travel', 'Personal Travel'}

# %%
data['Type of Travel']=data['Type of Travel'].map({'Business travel':1, 'Personal Travel':2})
data
#issue with NaN (The strings were not replaced with the numbers)
# Out:
#         satisfaction      Customer Type  Age  Type of Travel     Class  \
# 0          satisfied     Loyal Customer   65               2       Eco
# 1          satisfied     Loyal Customer   47               2  Business
# 2          satisfied     Loyal Customer   15               2       Eco
# 3          satisfied     Loyal Customer   60               2       Eco
# 4          satisfied     Loyal Customer   70               2       Eco
# ...              ...                ...  ...             ...       ...
# 129875     satisfied  disloyal Customer   29               2       Eco
# 129876  dissatisfied  disloyal Customer   63               2  Business
# 129877  dissatisfied  disloyal Customer   69               2       Eco
# 129878  dissatisfied  disloyal Customer   66               2       Eco
# 129879  dissatisfied  disloyal Customer   38               2       Eco
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# ...

# %%
label=data['satisfaction']

# %%
label
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 129875   NaN
# 129876   NaN
# 129877   NaN
# 129878   NaN
# 129879   NaN
# Name: satisfaction, Length: 129880, dtype: float64

# %%
data1=data.drop('satisfaction', axis=1)
data1.tail()
# Out:
#         Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 129875            NaN   29               2    NaN             1731
# 129876            NaN   63               2    NaN             2087
# 129877            NaN   69               2    NaN             2320
# 129878            NaN   66               2    NaN             2450
# 129879            NaN   38               2    NaN             4307
#
#         Seat comfort  Departure/Arrival time convenient  Food and drink  \
# 129875             5                                  5               5
# 129876             2                                  3               2
# 129877             3                                  0               3
# 129878             3                                  2               3
# 129879             3                                  4               3
#
#         Gate location  Inflight wifi service  ...  Online support  \
# ...

# %%
x_train, x_test, y_train,y_test=tts(data1, label, test_size=0.3)

# %%
x_train.head()
x_train.shape
# Out:
# (90916, 21)

# %%
# from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()
model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4772/521577407.py in <module>
#       1 model=LogisticRegression()
# ----> 2 model.fit(x_train, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1342             _dtype = [np.float64, np.float32]
#    1343
# -> 1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
# ...
